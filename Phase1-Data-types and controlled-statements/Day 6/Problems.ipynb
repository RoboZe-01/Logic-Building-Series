# %% [markdown]
# Got it — we’ll keep **Day 6** as a mix of **datatypes + problem-solving** but in **LeetCode-style statements** so you get comfortable with that format.
# We’ll go:
#
# * **Easy** → datatype-focused
# * **Medium** → logical & looping-based
# * **Hard** → real-world Python use-case, but tuned for your current level (not overkill)
#
# ---
#
# ## ✅ **Day 6: Datatypes + Problem Solving**
#
# ⏰ **Estimated Time**: 1.5 – 2 hours
# 🎯 **Focus**:
#
# * Practice with Python’s basic datatypes (list, tuple, dict, set, str, int, float)
# * Work with constraints and input/output format
# * Think step-by-step like solving a coding platform problem
#
# ---
#
# ### **🟢 Easy – Datatype Focus**
#
# **Problem Title**: *Unique Elements Count*
# **Difficulty**: Easy
#
# ---
#
# #### **Problem Statement**
#
# Given a list of integers `nums`, return the number of **unique elements** in the list.
# Two elements are considered the same if they have the same value.
#
# ---
#
# #### **Example 1**
#
# ```
# Input: nums = [1, 2, 2, 3, 4, 4]
# Output: 4
# Explanation: The unique numbers are {1, 2, 3, 4}, so the count is 4.
# ```
#
# ---
#
# #### **Constraints**
#
# * `1 <= len(nums) <= 10^5`
# * `-10^9 <= nums[i] <= 10^9`
#
# ---
#
# #### **Function Signature**
#
# ```python
# def count_unique(nums: list[int]) -> int:
#     pass
# ```
#
# 💡 *Hint*: Which datatype automatically stores only unique values?
#
# ---
#
# ### **🟡 Medium – Logic + Loops**
#
# **Problem Title**: *Sum of Digits Until Single Digit*
# **Difficulty**: Medium
#
# ---
#
# #### **Problem Statement**
#
# Given a positive integer `n`, repeatedly add all its digits until the result has only **one digit**, then return that digit.
#
# ---
#
# #### **Example 1**
#
# ```
# Input: n = 942
# Output: 6
# Explanation: 9+4+2 = 15 → 1+5 = 6
# ```
#
# ---
#
# #### **Example 2**
#
# ```
# Input: n = 38
# Output: 2
# Explanation: 3+8 = 11 → 1+1 = 2
# ```
#
# ---
#
# #### **Constraints**
#
# * `1 <= n <= 10^9`
#
# ---
#
# #### **Function Signature**
#
# ```python
# def digital_root(n: int) -> int:
#     pass
# ```
#
# 💡 *Hint*: Use a loop until the number has 1 digit. Think about string conversion vs. math operations.
#
# ---
#
# ### **🔴 Hard – Real-World Python Use-Case**
#
# **Problem Title**: *Student Grade Calculator*
# **Difficulty**: Hard (use-case level)
#
# ---
#
# #### **Problem Statement**
#
# You are given a list of student records where each record is a tuple:
# `(student_name, [marks_list])`
# Write a program that:
#
# 1. Calculates the **average marks** for each student.
# 2. Returns a dictionary where the key is the student name and the value is their grade:
#
#    * `A` if average >= 90
#    * `B` if 75 <= average < 90
#    * `C` if 60 <= average < 75
#    * `D` if average < 60
#
# ---
#
# #### **Example**
#
# ```
# Input: records = [
#   ("Alice", [85, 92, 88]),
#   ("Bob", [70, 75, 80]),
#   ("Charlie", [50, 60, 55])
# ]
# Output: {
#   "Alice": "A",
#   "Bob": "B",
#   "Charlie": "D"
# }
# ```
#
# ---
#
# #### **Constraints**
#
# * `1 <= len(records) <= 10^3`
# * `1 <= len(marks_list) <= 50`
# * `0 <= marks <= 100`
#
# ---
#
# #### **Function Signature**
#
# ```python
# def assign_grades(records: list[tuple[str, list[int]]]) -> dict[str, str]:
#     pass
# ```
#
# 💡 *Hints*:
#
# * You’ll need to iterate over each record
# * Use datatype conversions wisely (`sum()`, `len()` for averages)
# * Dictionary comprehension can make your solution cleaner
#
# ---
#
# ## 🧭 **Summary – Day 6**
#
# | Level  | Title                    | Key Focus                                  |
# | ------ | ------------------------ | ------------------------------------------ |
# | Easy   | Unique Elements Count    | Sets for uniqueness                        |
# | Medium | Digital Root             | Loops + number operations                  |
# | Hard   | Student Grade Calculator | Lists, tuples, dicts + real-world thinking |
#
# ---
#
# If you want, I can also **add hidden edge cases** for each problem so you test your code like an interviewer would.
# That way, when you run your solutions, you’ll know if they’re truly robust.
#
# Do you want me to give those hidden test cases for these Day 6 problems? That would level up your problem-solving mindset fast.
